# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv("../data/raw/filtered.tsv", sep = "\t", index_col = 0)
df["reference"] = df["reference"].apply(lambda x : x.lower())
train_df, val_df = train_test_split(df[["reference", "translation"]], test_size=0.02)
train_df.to_csv("../data/interim/train_df")
val_df.to_csv("../data/interim/val_df")

# %%
train_df = pd.read_csv("../data/interim/train_df", index_col = 0)
train_df
# Out:
#                                                 reference  ...   trn_tox
# 442535           We've wasted enough time on this wanker.  ...  0.002324
# 533425  "Maybe it was a dream-but it wasn't-or maybe I...  ...  0.969484
# 54800   Hell, it could've been four years with the shi...  ...  0.000040
# 259869     Go ahead, bang your head on the bars and yell.  ...  0.014461
# 19879   I'm just gonna blackmail her, so we don't have...  ...  0.962640
# ...                                                   ...  ...       ...
# 475662  There was no legal, professional, or ethical o...  ...  0.957680
# 533545                     We will cut them off, general!  ...  0.244485
# 123693         What the -- cyril, are you cheating on me?  ...  0.004033
# 567362            you filmed us having sex? you're upset?  ...  0.060329
# 573712  I can't even afford to buy my son a ticket to ...  ...  0.000100
#
# [566221 rows x 6 columns]
